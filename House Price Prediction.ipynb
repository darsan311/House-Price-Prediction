# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("HousePrices.csv")
df
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
pd.pandas.set_option("display.max_columns",None)

# %%
df
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.BsmtFullBath = df.BsmtFullBath.astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   category
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   category
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.GarageCars= df.GarageCars.astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   category
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   category
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   category
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   category
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %% [markdown]
# ### selecting out required dataset (6 IDV{2 category,4 numerical}, 1 DV)

# %%
drop=df[['BsmtFullBath','GarageCars','LotArea','TotalBsmtSF','GarageArea','GrLivArea','Property_Sale_Price']]
drop
# Out:
#      BsmtFullBath GarageCars  LotArea  TotalBsmtSF  GarageArea  GrLivArea  \
# 0               1          2     8450          856         548       1710
# 1               0          2     9600         1262         460       1262
# 2               1          2    11250          920         608       1786
# 3               1          3     9550          756         642       1717
# 4               1          3    14260         1145         836       2198
# ...           ...        ...      ...          ...         ...        ...
# 2068            1          2     8755          992         390       2060
# 2069            2          0     7711         1440           0       1440
# 2070            0          2    25000         1632         576       1632
# 2071            0          2    14375          819         525       1344
# 2072            0          2     8820         1088         456       1869
#
#       Property_Sale_Price
# 0                  208500
# ...

# %%
drop.isna().sum()   #drop is our final cleaned data with no missing values and no columns(name and year)
# Out:
# BsmtFullBath           0
# GarageCars             0
# LotArea                0
# TotalBsmtSF            0
# GarageArea             0
# GrLivArea              0
# Property_Sale_Price    0
# dtype: int64

# %% [markdown]
# ### Assigning dependent(y) and independent variable(2 cat and 4 numerical)=(x)

# %%
#IDV=independent variables
IDV=drop.iloc[:,0:6]
IDV
# Out:
#      BsmtFullBath GarageCars  LotArea  TotalBsmtSF  GarageArea  GrLivArea
# 0               1          2     8450          856         548       1710
# 1               0          2     9600         1262         460       1262
# 2               1          2    11250          920         608       1786
# 3               1          3     9550          756         642       1717
# 4               1          3    14260         1145         836       2198
# ...           ...        ...      ...          ...         ...        ...
# 2068            1          2     8755          992         390       2060
# 2069            2          0     7711         1440           0       1440
# 2070            0          2    25000         1632         576       1632
# 2071            0          2    14375          819         525       1344
# 2072            0          2     8820         1088         456       1869
#
# [2073 rows x 6 columns]

# %%
#DV= dependent
DV=drop.iloc[:,-1]
DV
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2068    214000
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 2073, dtype: int64

# %% [markdown]
# ### Applying Ttest to check linearity. we have 6 IDV and 1 DV we have to check each IDV with DV

# %%
#apply T-test-- pearsonr is used to cal t test
from scipy.stats import pearsonr

# %%
pearsonr(drop.BsmtFullBath,drop.Property_Sale_Price)
# Out:
# (0.21944068558168864, 5.059864585129446e-24)

# %%
r,p=pearsonr(drop.BsmtFullBath,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 5.059864585129446e-24

# %%
r,p=pearsonr(drop.GarageCars,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 1.9724233361675745e-233

# %%
r,p=pearsonr(drop.LotArea,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 2.0852284408736177e-22

# %%
r,p=pearsonr(drop.TotalBsmtSF,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 2.1390840069503147e-219

# %%
r,p=pearsonr(drop.GarageArea,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 2.0751502645932985e-221

# %%
r,p=pearsonr(drop.GrLivArea,drop.Property_Sale_Price)
if p>0.05:
    print("Not significant",p)
else:
    print("Significant",p)
# Out:
# Significant 5.78166e-319

# %% [markdown]
# ### to check Multicollinearity, we find correlation and for that we will use only Numerical IDV's

# %%
#used to check with heatmap
IDV.corr()
# Out:
#               LotArea  TotalBsmtSF  GarageArea  GrLivArea
# LotArea      1.000000     0.200794    0.144898   0.209442
# TotalBsmtSF  0.200794     1.000000    0.468849   0.424486
# GarageArea   0.144898     0.468849    1.000000   0.466201
# GrLivArea    0.209442     0.424486    0.466201   1.000000

# %%
sns.heatmap(IDV.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### We checked with IDV alone and multicollinearity exists since all are significant

# %%
for i in IDV.select_dtypes(exclude='category'):
    for j in IDV.select_dtypes(exclude='category'):
        correlation=0
        p_value=0
        if(i!=j):
            print("\nCorrelation between",i,"and",j,":")
            correlation,p_value=pearsonr(IDV[i],IDV[j])  
            print("Correlation = ",correlation,"\nP_value = ",p_value)
            if p_value>0.05:
                print("Not Significant.")
            else:
                print("Significant.")
            print()
# Out:
# Correlation between LotArea and TotalBsmtSF :
# Correlation =  0.20079352138592987
# P_value =  2.685646408500276e-20
# Significant.
#
#
# Correlation between LotArea and GarageArea :
# Correlation =  0.14489821148826712
# P_value =  3.396331442540775e-11
# Significant.
#
#
# Correlation between LotArea and GrLivArea :
# Correlation =  0.20944240231201555
# P_value =  5.564194054602473e-22
# Significant.
#
#
# Correlation between TotalBsmtSF and LotArea :
# Correlation =  0.20079352138592987
# P_value =  2.685646408500276e-20
# Significant.
#
#
# Correlation between TotalBsmtSF and GarageArea :
# Correlation =  0.4688494061437083
# P_value =  8.70738391664317e-114
# Significant.
#
#
# Correlation between TotalBsmtSF and GrLivArea :
# Correlation =  0.4244857496775535
# P_value =  1.8451466700628437e-91
# Significant.
#
#
# Correlation between GarageArea and LotArea :
# Correlation =  0.14489821148826712
# P_value =  3.396331442540775e-11
# Significant.
#
#
# ...

# %% [markdown]
# ### we are going to find correlation between 4 numerical IDVs and 1 Dv. for that we are excluding the categorical values (origin,cylinder) from drop and storing it as drop_cat
#
# doubt? why to do this?

# %%
drop_category=drop.iloc[:,2:7]
drop_category
# Out:
#       LotArea  TotalBsmtSF  GarageArea  GrLivArea  Property_Sale_Price
# 0        8450          856         548       1710               208500
# 1        9600         1262         460       1262               181500
# 2       11250          920         608       1786               223500
# 3        9550          756         642       1717               140000
# 4       14260         1145         836       2198               250000
# ...       ...          ...         ...        ...                  ...
# 2068     8755          992         390       2060               214000
# 2069     7711         1440           0       1440               150000
# 2070    25000         1632         576       1632               143000
# 2071    14375          819         525       1344               137500
# 2072     8820         1088         456       1869               124900
#
# [2073 rows x 5 columns]

# %%
drop_category.corr()
# Out:
#                       LotArea  TotalBsmtSF  GarageArea  GrLivArea  \
# LotArea              1.000000     0.200794    0.144898   0.209442
# TotalBsmtSF          0.200794     1.000000    0.468849   0.424486
# GarageArea           0.144898     0.468849    1.000000   0.466201
# GrLivArea            0.209442     0.424486    0.466201   1.000000
# Property_Sale_Price  0.211572     0.618828    0.621049   0.710938
#
#                      Property_Sale_Price
# LotArea                         0.211572
# TotalBsmtSF                     0.618828
# GarageArea                      0.621049
# GrLivArea                       0.710938
# Property_Sale_Price             1.000000

# %%
sns.heatmap(drop_category.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
for i in drop_category.select_dtypes(exclude='category'):
    for j in drop_category.select_dtypes(exclude='category'):
        correlation=0
        p_value=0
        if(i!=j):
            print("\nCorrelation between",i,"and",j,":")
            correlation,p_value=pearsonr(drop_category[i],drop_category[j])  
            print("Correlation = ",correlation,"\nP_value = ",p_value)
            if p_value>0.05:
                print("Not Significant.")
            else:
                print("Significant.")
            print()
# Out:
# Correlation between LotArea and TotalBsmtSF :
# Correlation =  0.20079352138592987
# P_value =  2.685646408500276e-20
# Significant.
#
#
# Correlation between LotArea and GarageArea :
# Correlation =  0.14489821148826712
# P_value =  3.396331442540775e-11
# Significant.
#
#
# Correlation between LotArea and GrLivArea :
# Correlation =  0.20944240231201555
# P_value =  5.564194054602473e-22
# Significant.
#
#
# Correlation between LotArea and Property_Sale_Price :
# Correlation =  0.21157220776166596
# P_value =  2.0852284408736177e-22
# Significant.
#
#
# Correlation between TotalBsmtSF and LotArea :
# Correlation =  0.20079352138592987
# P_value =  2.685646408500276e-20
# Significant.
#
#
# Correlation between TotalBsmtSF and GarageArea :
# Correlation =  0.4688494061437083
# P_value =  8.70738391664317e-114
# Significant.
#
#
# Correlation between TotalBsmtSF and GrLivArea :
# Correlation =  0.4244857496775535
# P_value =  1.8451466700628437e-91
# Significant.
#
#
# ...

# %% [markdown]
# ### To check Normality of errors

# %% [markdown]
# ### we are using shapiro because dataselt is below 5000.
# #if >5000 use Anderson ;
# As a rule of thumb, we reject the null hypothesis if p < 0.05.

# %%
from scipy.stats import anderson,shapiro,kstest
from scipy import stats
shapiro_test = stats.shapiro(drop.Property_Sale_Price)
shapiro_test
# Out:
# ShapiroResult(statistic=0.8739097714424133, pvalue=5.03303528652466e-38)

# %%
s,p=shapiro(drop.Property_Sale_Price)
if p>0.05:
    print("Significant")
else:
    print("Not Significant")
# Out:
# Not Significant

# %% [markdown]
# ### Feature Transformation technique for Normality check ,since the normality cheked using shapiro is not significant
# #FT has 4 types where in this case we use LOG TRANSFORMATION
#
# #doubt why we use log??

# %%
np.log10(drop_category.Property_Sale_Price)
# Out:
# 0       5.319106
# 1       5.258877
# 2       5.349278
# 3       5.146128
# 4       5.397940
#           ...
# 2068    5.330414
# 2069    5.176091
# 2070    5.155336
# 2071    5.138303
# 2072    5.096562
# Name: Property_Sale_Price, Length: 2073, dtype: float64

# %% [markdown]
# ### To build Linear model

# %%
from sklearn.model_selection import train_test_split

# %%
x=drop.iloc[:,:-1]   #independent variables stored in x
x
# Out:
#      BsmtFullBath GarageCars  LotArea  TotalBsmtSF  GarageArea  GrLivArea
# 0               1          2     8450          856         548       1710
# 1               0          2     9600         1262         460       1262
# 2               1          2    11250          920         608       1786
# 3               1          3     9550          756         642       1717
# 4               1          3    14260         1145         836       2198
# ...           ...        ...      ...          ...         ...        ...
# 2068            1          2     8755          992         390       2060
# 2069            2          0     7711         1440           0       1440
# 2070            0          2    25000         1632         576       1632
# 2071            0          2    14375          819         525       1344
# 2072            0          2     8820         1088         456       1869
#
# [2073 rows x 6 columns]

# %%
y=drop.iloc[:,-1]   #dependent values stored in y
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2068    214000
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 2073, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)  # test size=30% and train size =70%

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1451, 6)
# (622, 6)
# (1451,)
# (622,)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()  #storing LR in variable l

# %%
l.fit(x_train,y_train) #fit x and y train and assign in l
# Out:
# LinearRegression()

# %%
l.coef_  #y=mx+c ; coeff is m value (wherein m is slope)
# Out:
# array([ 1.64444140e+04,  3.30628486e+04, -1.18431462e-01,  4.59001730e+01,
#         3.69757637e+00,  6.85641169e+01])

# %%
l.intercept_   #intercept is c value
# Out:
# -37469.995945660834

# %% [markdown]
# ### To find Train RMSE
#
#
# Things to find:
#
# Train_pred
#
#
# Error for train data
#
# KDE Plot
#
# find the mean squared error for train
#
# find the R sqaured value for train

# %%
train_pred=l.predict(x_train)
train_pred
# Out:
# array([231934.18790217, 154333.54494092, 173159.18192467, ...,
#        120740.43697136, 214917.84023718, 184101.45073662])

# %%
error=y_train-train_pred

# %%
error   #error for train data
# Out:
# 283     12665.812098
# 1363     2598.455059
# 858    -21159.181925
# 347    -56535.335067
# 1261    13006.804128
#             ...
# 129      1168.412424
# 27      31294.713451
# 1488    -1740.436971
# 1320   -58417.840237
# 1329    -7601.450737
# Name: Property_Sale_Price, Length: 1451, dtype: float64

# %%
sns.kdeplot(error)
# Out:
# <AxesSubplot:xlabel='Property_Sale_Price', ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(train_pred,y_train)
# Out:
# 1942471142.2907255

# %%
np.sqrt(mean_squared_error(train_pred,y_train))     #Train RMSE
# Out:
# 44073.474361465145

# %%
r2_score(y_train,train_pred)   # R sq of Train RMSE
# Out:
# 0.7013284544508913

# %% [markdown]
# ### To find Test RMSE
#
#
# Things to find:
#
# Test_pred
#
#
# Error for test data
#
# KDE Plot
#
# find the mean squared error for test
#
# find the R sqaured value for test

# %%
test_pred=l.predict(x_test)
test_pred
# Out:
# array([322871.39512672, 245354.02820919,  90980.26007806,  89734.94761415,
#        245455.18258012, 189106.52121588, 128208.93577132, 201235.59481493,
#        128089.28631645, 101893.65763408, 173322.43440743,  89190.22576571,
#        182448.16845832, 222450.99859144, 178231.4309108 , 193300.74747282,
#        183057.86859138, 175509.43580649, 169292.72457159, 107512.9409638 ,
#        160465.81093897, 180833.64656772, 190767.24554791,  95339.89852889,
#        291907.1626187 ,  71119.51460931,  55252.74120248, 144883.70161296,
#        152236.08504316, 115683.44116978, 115887.36217014, 184342.71850299,
#        115275.40156012, 266429.30034199, 100662.65842894, 208249.60911263,
#        152166.1424305 , 162428.52580551,  67053.09616667,  93819.3575783 ,
#        104619.44810075,  53239.86679369, 101270.67956237, 187590.78099719,
#        175262.83096217,  76687.04984083, 169086.61330708, 194654.01731602,
# ...

# %%
error2=y_test-test_pred

# %%
error2
# Out:
# 1580    61098.604873
# 1330   -18354.028209
# 1453    -6480.260078
# 613     57265.052386
# 1538    10844.817420
#             ...
# 944    -21136.891450
# 1135    -5194.895351
# 841     -7811.102600
# 1639    63081.528308
# 55     -12192.078303
# Name: Property_Sale_Price, Length: 622, dtype: float64

# %%
sns.kdeplot(error2)
# Out:
# <AxesSubplot:xlabel='Property_Sale_Price', ylabel='Density'>

# %%
mean_squared_error(test_pred,y_test)
# Out:
# 1626765040.7056892

# %%
np.sqrt(mean_squared_error(test_pred,y_test))   #Test RMSE
# Out:
# 40333.17543543639

# %%
r2_score(y_test,test_pred)    #test r sq
# Out:
# 0.6990364444131208

# %% [markdown]
# ### now check hetroscadacity

# %%
import statsmodels.api as sm

# %% [markdown]
# ### adding constant in x_train and assigning it in x_train1 to perform matrix multiplication
#
# note: it cant be added in y(dependent variable)

# %%
x_train1=sm.add_constant(x_train)
x_train1
# Out:
#       const BsmtFullBath GarageCars  LotArea  TotalBsmtSF  GarageArea  \
# 283     1.0            0          3     9612         1468         898
# 1363    1.0            0          2     8499          616         432
# 858     1.0            0          2    10400         1090         479
# 347     1.0            1          2    17600         1478         498
# 1261    1.0            0          1     9600         1050         338
# ...     ...          ...        ...      ...          ...         ...
# 129     1.0            0          2     8973         1008         750
# 27      1.0            1          3    11478         1704         772
# 1488    1.0            1          1     7129          948         280
# 1320    1.0            1          2     8400         1478         442
# 1329    1.0            0          2     9084          935         462
#
#       GrLivArea
# 283        1468
# 1363       1412
# 858        1370
# 347        1478
# 1261       1050
# ...         ...
# ...

# %%
model=sm.OLS(y_train,x_train1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Property_Sale_Price   R-squared:                       0.701
# Model:                             OLS   Adj. R-squared:                  0.700
# Method:                  Least Squares   F-statistic:                     565.1
# Date:                 Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                         22:16:45   Log-Likelihood:                -17575.
# No. Observations:                 1451   AIC:                         3.516e+04
# Df Residuals:                     1444   BIC:                         3.520e+04
# Df Model:                            6
# Covariance Type:             nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### VISUALIZATION

# %% [markdown]
# #### UNIVARIATE2

# %%
sns.boxplot(drop['GarageArea'])
plt.show()
# Out:
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(drop['TotalBsmtSF'])
plt.show()
# Out:
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.hist(drop['LotArea'])
plt.show()

# %%
plt.hist(drop['GrLivArea'])
plt.show()

# %% [markdown]
# ## BIVARIATE

# %%
sns.heatmap(drop.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(drop.GarageArea,drop.Property_Sale_Price)

# %% [markdown]
# ## MULTIVARIATE

# %%
sns.pairplot(drop,size=4)
plt.show()
# Out:
# D:\Anacoda\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
